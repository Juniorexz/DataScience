# %%
import pandas as pd
import zipfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import zipfile

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Tcc/microdados_enem_2018.zip') as z:
  print(*z.namelist(),sep="\n")
# Out:
# DICION╡RIO/
# DICION╡RIO/Dicionário_Microdados_Enem_2018.ods
# DICION╡RIO/Dicionário_Microdados_Enem_2018.xlsx
# INPUTS/
# INPUTS/INPUT_R_ITENS_PROVA_2018.R
# INPUTS/INPUT_R_MICRODADOS_ENEM_2018.R
# INPUTS/INPUT_SAS_ITENS_PROVA_2018.sas
# INPUTS/INPUT_SAS_MICRODADOS_ENEM_2018.sas
# INPUTS/INPUT_SPSS_ITENS_PROVA_2018.sps
# INPUTS/INPUT_SPSS_MICRODADOS_ENEM_2018.sps
# LEIA-ME E DOCUMENTOS TÉCNICOS/
# LEIA-ME E DOCUMENTOS TÉCNICOS/edital_enem_2018.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/enem_procedimentos_de_analise.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/entenda_a_sua_nota_no_enem_guia_do_participante.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/Leia_Me_Enem_2018.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/manual_de_redacao_do_enem_2018.pdf
# LEIA-ME E DOCUMENTOS TÉCNICOS/matriz_referencia.pdf
# PROVAS E GABARITOS/
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_01_DIA_1_AZUL.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_01_DIA_1_AZUL_AMPLIADA.pdf
# PROVAS E GABARITOS/ENEM_2018_P1_CAD_01_DIA_1_AZUL_SUPERAMPLIADA.pdf
# ...

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Tcc/microdados_enem_2018.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2018.csv') as f:
    df = pd.read_csv(f, sep=';', encoding='ISO-8859-1')

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Tcc/microdados_enem_2018.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2018.csv') as f:
    df = pd.read_csv(f, sep=';', encoding='ISO-8859-1', nrows=0)

# %%
df
# Out:
# Empty DataFrame
# Columns: [NU_INSCRICAO, NU_ANO, TP_FAIXA_ETARIA, TP_SEXO, TP_ESTADO_CIVIL, TP_COR_RACA, TP_NACIONALIDADE, TP_ST_CONCLUSAO, TP_ANO_CONCLUIU, TP_ESCOLA, TP_ENSINO, IN_TREINEIRO, CO_MUNICIPIO_ESC, NO_MUNICIPIO_ESC, CO_UF_ESC, SG_UF_ESC, TP_DEPENDENCIA_ADM_ESC, TP_LOCALIZACAO_ESC, TP_SIT_FUNC_ESC, CO_MUNICIPIO_PROVA, NO_MUNICIPIO_PROVA, CO_UF_PROVA, SG_UF_PROVA, TP_PRESENCA_CN, TP_PRESENCA_CH, TP_PRESENCA_LC, TP_PRESENCA_MT, CO_PROVA_CN, CO_PROVA_CH, CO_PROVA_LC, CO_PROVA_MT, NU_NOTA_CN, NU_NOTA_CH, NU_NOTA_LC, NU_NOTA_MT, TX_RESPOSTAS_CN, TX_RESPOSTAS_CH, TX_RESPOSTAS_LC, TX_RESPOSTAS_MT, TP_LINGUA, TX_GABARITO_CN, TX_GABARITO_CH, TX_GABARITO_LC, TX_GABARITO_MT, TP_STATUS_REDACAO, NU_NOTA_COMP1, NU_NOTA_COMP2, NU_NOTA_COMP3, NU_NOTA_COMP4, NU_NOTA_COMP5, NU_NOTA_REDACAO, Q001, Q002, Q003, Q004, Q005, Q006, Q007, Q008, Q009, Q010, Q011, Q012, Q013, Q014, Q015, Q016, Q017, Q018, Q019, Q020, Q021, Q022, Q023, Q024, Q025, Q026, Q027]
# Index: []
#
# [0 rows x 78 columns]

# %%
df.columns.values #Assim exibe todas as colunas que tenho na minha base de dados
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
columns = ['IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
       'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
       'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
       'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
       'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
       'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
       'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT','TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
       'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
       'NU_NOTA_REDACAO', 'Q001', 'Q002', 'Q003', 'Q004', 'Q005', 'Q006',
       'Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014',
       'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022',
       'Q023', 'Q024', 'Q025', 'Q026', 'Q027']

# %%
with zipfile.ZipFile('/content/drive/MyDrive/Tcc/microdados_enem_2018.zip') as z:
  with z.open('DADOS/MICRODADOS_ENEM_2018.csv') as f:
    df = pd.read_csv(f,sep=';', encoding='ISO-8859-1', usecols=columns)

# %%
df.head()
# Out:
#    IN_TREINEIRO  CO_MUNICIPIO_ESC    NO_MUNICIPIO_ESC  CO_UF_ESC SG_UF_ESC  \
# 0             0         1500800.0          Ananindeua       15.0        PA
# 1             0               NaN                 NaN        NaN       NaN
# 2             0         3155603.0  Rio Pardo de Minas       31.0        MG
# 3             0         1500800.0          Ananindeua       15.0        PA
# 4             0               NaN                 NaN        NaN       NaN
#
#    TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC  TP_SIT_FUNC_ESC  \
# 0                     4.0                 1.0              1.0
# 1                     NaN                 NaN              NaN
# 2                     2.0                 1.0              1.0
# 3                     4.0                 1.0              1.0
# 4                     NaN                 NaN              NaN
#
#    CO_MUNICIPIO_PROVA  NO_MUNICIPIO_PROVA  ...  Q018 Q019  Q020  Q021  Q022  \
# ...

# %%
df.NU_I
