# %% [markdown]
# <a href="https://colab.research.google.com/github/Juniorexz/DataScience/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Criando **nomes**

# %%
      import pandas as pd

# %%
nomes_f = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-f.json')
nomes_m = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-m.json')

# %%
nomes_m
# Out:
#           nome  regiao     freq  rank sexo
# 0         JOSE       0  5732508     1    M
# 1         JOAO       0  2971935     2    M
# 2      ANTONIO       0  2567494     3    M
# 3    FRANCISCO       0  1765197     4    M
# 4       CARLOS       0  1483121     5    M
# ..         ...     ...      ...   ...  ...
# 195     WALTER       0    67207   196    M
# 196    ARLINDO       0    66669   197    M
# 197    MICHAEL       0    65736   198    M
# 198     ALVARO       0    65444   199    M
# 199    GEOVANE       0    65435   200    M
#
# [200 rows x 5 columns]

# %%
nomes_f.sample(5)
# Out:
#            nome  regiao    freq  rank sexo
# 94      SABRINA       0  179037    95    F
# 178  ELIZANGELA       0   88505   179    F
# 177     JENIFER       0   88574   178    F
# 91        CELIA       0  184096    92    F
# 194       CLARA       0   82626   195    F

# %%
nomes_m.sample(5)
# Out:
#           nome  regiao    freq  rank sexo
# 77       ELIAS       0  189315    78    M
# 148  APARECIDO       0   93950   149    M
# 64      ROBSON       0  235386    65    M
# 37       EDSON       0  430171    38    M
# 83       RENAN       0  170182    84    M

# %%
print('Quantidade de nomes:' + str(len(nomes_f) + len(nomes_m)))
#Conta necessária para converter a str e fazer a soma dos nomes
# Out:
# Quantidade de nomes:400

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()
nomes.sample(5)
# Out:
#            nome
# 37    ROSANGELA
# 76      TATIANE
# 102       HELIO
# 3     FRANCISCO
# 126  SEBASTIANA

# %% [markdown]
# Incluindo ID dos alunos

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 400

# %%
nomes["id_aluno"] = np.random.permutation(total_alunos) + 1

# %%
nomes.sample(3)
# Out:
#           nome  id_aluno
# 188    POLIANA       369
# 57      DAIANE       303
# 3    FRANCISCO       382

# %%
nomes.sample(5)
# Out:
#         nome  id_aluno
# 46   FABIANA       358
# 159    SELMA       118
# 3    ANTONIA       156
# 97   BARBARA       201
# 64    ROBSON       290

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)

# %%
nomes
# Out:
#           nome  id_aluno                 dominio
# 0        MARIA       235     @servicodoemail.com
# 1          ANA        43     @servicodoemail.com
# 2    FRANCISCA       304  @dominiodoemail.com.br
# 3      ANTONIA       156  @dominiodoemail.com.br
# 4      ADRIANA       343  @dominiodoemail.com.br
# ..         ...       ...                     ...
# 195     WALTER       231     @servicodoemail.com
# 196    ARLINDO        99  @dominiodoemail.com.br
# 197    MICHAEL       323  @dominiodoemail.com.br
# 198     ALVARO       383     @servicodoemail.com
# 199    GEOVANE       366  @dominiodoemail.com.br
#
# [400 rows x 3 columns]

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio
# 190  NATANAEL        58     @servicodoemail.com
# 104  REINALDO        28     @servicodoemail.com
# 193  LUCILENE       146     @servicodoemail.com
# 98      THAIS       148  @dominiodoemail.com.br
# 2     ANTONIO       205  @dominiodoemail.com.br

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample()
# Out:
#        nome  id_aluno              dominio                      email
# 101  SILVIO       363  @servicodoemail.com  silvio@servicodoemail.com

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio  \
# 193     KAUAN        84  @dominiodoemail.com.br
# 187    NAIARA       229  @dominiodoemail.com.br
# 134  VERONICA       274  @dominiodoemail.com.br
# 59     ISABEL        83  @dominiodoemail.com.br
# 51      JOANA       102     @servicodoemail.com
#
#                               email
# 193     kauan@dominiodoemail.com.br
# 187    naiara@dominiodoemail.com.br
# 134  veronica@dominiodoemail.com.br
# 59     isabel@dominiodoemail.com.br
# 51         joana@servicodoemail.com

# %% [markdown]
# #Criando a Tabela Cursos

# %%
# !pip3 install html5lib
# !pip3 install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: html5lib in /usr/local/lib/python3.7/dist-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from html5lib) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from html5lib) (0.5.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (4.9.1)

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos[0]
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
nomes.sample(3)
# Out:
#          nome  id_aluno                 dominio  \
# 171  VALDEMIR         3  @dominiodoemail.com.br
# 67   HENRIQUE        64     @servicodoemail.com
# 167    ANGELO        85  @dominiodoemail.com.br
#
#                               email
# 171  valdemir@dominiodoemail.com.br
# 67      henrique@servicodoemail.com
# 167    angelo@dominiodoemail.com.br

# %% [markdown]
# **Matriculando os alunos nos cursos**

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio                         email
# 112   TATIANA       161     @servicodoemail.com    tatiana@servicodoemail.com
# 74       ALAN       355  @dominiodoemail.com.br    alan@dominiodoemail.com.br
# 18   RAIMUNDO        70     @servicodoemail.com   raimundo@servicodoemail.com
# 105    MILENA       371     @servicodoemail.com     milena@servicodoemail.com
# 85     HELENA       221  @dominiodoemail.com.br  helena@dominiodoemail.com.br

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 131   BRENO       187     @servicodoemail.com      breno@servicodoemail.com
# 48   RENATO       384     @servicodoemail.com     renato@servicodoemail.com
# 191   ERICK       124     @servicodoemail.com      erick@servicodoemail.com
# 10     LUIS       125  @dominiodoemail.com.br    luis@dominiodoemail.com.br
# 6    MARCIA        55  @dominiodoemail.com.br  marcia@dominiodoemail.com.br
#
#      matriculas
# 131           3
# 48            5
# 191           1
# 10            1
# 6             4

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       2.032500
# std        1.292525
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        8.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt

# %%
nomes.matriculas.value_counts()
# Out:
# 1    183
# 2    107
# 3     63
# 4     22
# 5     15
# 6      7
# 7      2
# 8      1
# Name: matriculas, dtype: int64

# %%
#Criando o banco sql

# %%
# !pip install sqlalchemy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (1.4.39)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.8.1)

# %%
from sqlalchemy import create_engine, MetaData, Table

# %%
engine = create_engine('sqlite:///:memory:')

# %%
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
#Matriculando os alunos nos cursos

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                 dominio  \
# 52      LUZIA       276     @servicodoemail.com
# 171  VALDEMIR         3  @dominiodoemail.com.br
# 133      RUAN       130     @servicodoemail.com
# 9       ALINE        92     @servicodoemail.com
# 139     OSMAR        71  @dominiodoemail.com.br
#
#                               email  matriculas
# 52         luzia@servicodoemail.com           1
# 171  valdemir@dominiodoemail.com.br           1
# 133         ruan@servicodoemail.com           1
# 9          aline@servicodoemail.com           3
# 139     osmar@dominiodoemail.com.br           1

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       2.032500
# std        1.292525
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        8.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
nomes.matriculas.value_counts()
# Out:
# 1    183
# 2    107
# 3     63
# 4     22
# 5     15
# 6      7
# 7      2
# 8      1
# Name: matriculas, dtype: int64

# %%
nomes.sample(5)
# Out:
#         nome  id_aluno                 dominio                          email  \
# 58      DAVI       131     @servicodoemail.com        davi@servicodoemail.com
# 93    ELIANA       372     @servicodoemail.com      eliana@servicodoemail.com
# 137  AUGUSTO       376  @dominiodoemail.com.br  augusto@dominiodoemail.com.br
# 145    ITALO       206  @dominiodoemail.com.br    italo@dominiodoemail.com.br
# 162   ISMAEL       100  @dominiodoemail.com.br   ismael@dominiodoemail.com.br
#
#      matriculas
# 58            3
# 93            4
# 137           5
# 145           1
# 162           3

# %% [markdown]
# #Selecionando Cursos

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 27    LUANA       240  @dominiodoemail.com.br   luana@dominiodoemail.com.br
# 45  ANDREIA        37     @servicodoemail.com    andreia@servicodoemail.com
# 17   FELIPE       113  @dominiodoemail.com.br  felipe@dominiodoemail.com.br
#
#     matriculas
# 27           1
# 45           2
# 17           5

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
  id = row.id_aluno
  matriculas = row.matriculas
  for i in range(matriculas):
    mat = [id, np.random.choice(cursos.index, p = prob)]
    todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno','id_curso'])

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0       235        11
# 1        43         3
# 2        43         2
# 3       304        18
# 4       304        16

# %%
matriculas.groupby('id_curso').count().join(cursos['Nome do curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                        Nome do curso
# id_curso
# 0                           30                Lógica de programação
# 1                           63                        Java para Web
# 2                           66                          C# para Web
# 3                           56                        Ruby on Rails
# 4                           19                     Cursos de Python
# 5                            3                        PHP com MySql
# 6                           68                        .NET para web
# 7                           53           Novas integrações com Java
# 8                           29                         TDD com Java
# 9                           53                  Código limpo com C#
# 10                          26  Preparatório para certificação Java
# 11                          39                      Hardware básico
# 12                          34                Persistência com .NET
# 13                          14                  Desenvolvendo jogos
# 14                          34                     Análise de dados
# 15                          29                   Estatística básica
# 16                          66                  Internet das coisas
# 17                          45                Programação funcional
# 18                          40                Boas práticas em Java
# 19                          46          Orientação objetos com Java

# %%
nomes.sample(3)
# Out:
#         nome  id_aluno              dominio                       email  \
# 36   ROBERTO       364  @servicodoemail.com  roberto@servicodoemail.com
# 130   JUNIOR       184  @servicodoemail.com   junior@servicodoemail.com
# 147  ALISSON       315  @servicodoemail.com  alisson@servicodoemail.com
#
#      matriculas
# 36            1
# 130           1
# 147           1

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0       235        11
# 1        43         3
# 2        43         2
# 3       304        18
# 4       304        16

# %%
matriculas.groupby('id_curso').count().join(cursos['Nome do curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})
# Out:
#           quantidade_de_alunos                        Nome do curso
# id_curso
# 0                           30                Lógica de programação
# 1                           63                        Java para Web
# 2                           66                          C# para Web
# 3                           56                        Ruby on Rails
# 4                           19                     Cursos de Python
# 5                            3                        PHP com MySql
# 6                           68                        .NET para web
# 7                           53           Novas integrações com Java
# 8                           29                         TDD com Java
# 9                           53                  Código limpo com C#
# 10                          26  Preparatório para certificação Java
# 11                          39                      Hardware básico
# 12                          34                Persistência com .NET
# 13                          14                  Desenvolvendo jogos
# 14                          34                     Análise de dados
# 15                          29                   Estatística básica
# 16                          66                  Internet das coisas
# 17                          45                Programação funcional
# 18                          40                Boas práticas em Java
# 19                          46          Orientação objetos com Java

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['Nome do curso']).rename(columns={'id_aluno':'quantidade_de_alunos'})

# %%
matriculas_por_curso
# Out:
#           quantidade_de_alunos                        Nome do curso
# id_curso
# 0                           30                Lógica de programação
# 1                           63                        Java para Web
# 2                           66                          C# para Web
# 3                           56                        Ruby on Rails
# 4                           19                     Cursos de Python
# 5                            3                        PHP com MySql
# 6                           68                        .NET para web
# 7                           53           Novas integrações com Java
# 8                           29                         TDD com Java
# 9                           53                  Código limpo com C#
# 10                          26  Preparatório para certificação Java
# 11                          39                      Hardware básico
# 12                          34                Persistência com .NET
# 13                          14                  Desenvolvendo jogos
# 14                          34                     Análise de dados
# 15                          29                   Estatística básica
# 16                          66                  Internet das coisas
# 17                          45                Programação funcional
# 18                          40                Boas práticas em Java
# 19                          46          Orientação objetos com Java

# %%
matriculas_por_curso.head(3)
# Out:
#           quantidade_de_alunos          Nome do curso
# id_curso
# 0                           30  Lógica de programação
# 1                           63          Java para Web
# 2                           66            C# para Web

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index=False)

# %%
pd.read_csv('matriculas_por_curso.csv')
# Out:
#     quantidade_de_alunos                        Nome do curso
# 0                     30                Lógica de programação
# 1                     63                        Java para Web
# 2                     66                          C# para Web
# 3                     56                        Ruby on Rails
# 4                     19                     Cursos de Python
# 5                      3                        PHP com MySql
# 6                     68                        .NET para web
# 7                     53           Novas integrações com Java
# 8                     29                         TDD com Java
# 9                     53                  Código limpo com C#
# 10                    26  Preparatório para certificação Java
# 11                    39                      Hardware básico
# 12                    34                Persistência com .NET
# 13                    14                  Desenvolvendo jogos
# 14                    34                     Análise de dados
# 15                    29                   Estatística básica
# 16                    66                  Internet das coisas
# 17                    45                Programação funcional
# 18                    40                Boas práticas em Java
# 19                    46          Orientação objetos com Java

# %%
matriculas_json = matriculas_por_curso.to_json()

# %%
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"0":30,"1":63,"2":66,"3":56,"4":19,"5":3,"6":68,"7":53,"8":29,"9":53,"10":26,"11":39,"12":34,"13":14,"14":34,"15":29,"16":66,"17":45,"18":40,"19":46},"Nome do curso":{"0":"L\\u00f3gica de programa\\u00e7\\u00e3o","1":"Java para Web","2":"C# para Web","3":"Ruby on Rails","4":"Cursos de Python","5":"PHP com MySql","6":".NET para web","7":"Novas integra\\u00e7\\u00f5es com Java","8":"TDD com Java","9":"C\\u00f3digo limpo com C#","10":"Preparat\\u00f3rio para certifica\\u00e7\\u00e3o Java","11":"Hardware b\\u00e1sico","12":"Persist\\u00eancia com .NET","13":"Desenvolvendo jogos","14":"An\\u00e1lise de dados","15":"Estat\\u00edstica b\\u00e1sica","16":"Internet das coisas","17":"Programa\\u00e7\\u00e3o funcional","18":"Boas pr\\u00e1ticas em Java","19":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %%
matriculas_html = matriculas_por_curso.to_html()

# %%
matriculas_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>quantidade_de_alunos</th>\n      <th>Nome do curso</th>\n    </tr>\n    <tr>\n      <th>id_curso</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>30</td>\n      <td>Lógica de programação</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>63</td>\n      <td>Java para Web</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>66</td>\n      <td>C# para Web</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>56</td>\n      <td>Ruby on Rails</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>19</td>\n      <td>Cursos de Python</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>3</td>\n      <td>PHP com MySql</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>68</td>\n      <td>.NET para web</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>53</td>\n      <td>Novas integrações com Java</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>29</td>\n      <td>TDD com Java</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>53</td>\n      <td>Código limpo com C#</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>26</td>\n      <td>Preparatório para certificação Java</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>39</td>\n      <td>Hardware básico</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>34</td>\n      <td>Persistência com .NET</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>14</td>\n      <td>Desenvolvendo jogos</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>34</td>\n      <td>Análise de dados</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>29</td>\n      <td>Estatística básica</td>\n    </tr>\n    <tr>\n      <th>16</th>\n      <td>66</td>\n      <td>Internet das coisas</td>\n    </tr>\n    <tr>\n      <th>17</th>\n      <td>45</td>\n      <td>Programação funcional</td>\n    </tr>\n    <tr>\n      <th>18</th>\n      <td>40</td>\n      <td>Boas práticas em Java</td>\n    </tr>\n    <tr>\n      <th>19</th>\n      <td>46</td>\n      <td>Orientação objetos com Java</td>\n    </tr>\n  </tbody>\n</table>'

# %%
print(matriculas_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_de_alunos</th>
#       <th>Nome do curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>63</td>
#       <td>Java para Web</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>66</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>56</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>19</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>PHP com MySql</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>68</td>
#       <td>.NET para web</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>53</td>
#       <td>Novas integrações com Java</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>29</td>
#       <td>TDD com Java</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>53</td>
#       <td>Código limpo com C#</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>26</td>
#       <td>Preparatório para certificação Java</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>39</td>
#       <td>Hardware básico</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>34</td>
#       <td>Persistência com .NET</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>Desenvolvendo jogos</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>34</td>
#       <td>Análise de dados</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>29</td>
#       <td>Estatística básica</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>66</td>
#       <td>Internet das coisas</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>45</td>
#       <td>Programação funcional</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>40</td>
#       <td>Boas práticas em Java</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>46</td>
#       <td>Orientação objetos com Java</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Criando o banco sql

# %%
# !pip install sqlalchemy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (1.4.39)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy) (3.8.1)

# %%
from sqlalchemy import create_engine, MetaData, Table

# %%
engine = create_engine('sqlite:///:memory:')

# %%
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
matriculas_por_curso.to_sql('matriculas', engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Buscando do banco sql

# %%
query = 'select * from matriculas where quantidade_de_alunos < 20'

# %%
pd.read_sql(query, engine)
# Out:
#    id_curso  quantidade_de_alunos        Nome do curso
# 0         4                    19     Cursos de Python
# 1         5                     3        PHP com MySql
# 2        13                    14  Desenvolvendo jogos

# %%
pd.read_sql_table('matriculas', engine, columns=['Nome do curso', 'quantidade_de_alunos'])
# Out:
#                           Nome do curso  quantidade_de_alunos
# 0                 Lógica de programação                    30
# 1                         Java para Web                    63
# 2                           C# para Web                    66
# 3                         Ruby on Rails                    56
# 4                      Cursos de Python                    19
# 5                         PHP com MySql                     3
# 6                         .NET para web                    68
# 7            Novas integrações com Java                    53
# 8                          TDD com Java                    29
# 9                   Código limpo com C#                    53
# 10  Preparatório para certificação Java                    26
# 11                      Hardware básico                    39
# 12                Persistência com .NET                    34
# 13                  Desenvolvendo jogos                    14
# 14                     Análise de dados                    34
# 15                   Estatística básica                    29
# 16                  Internet das coisas                    66
# 17                Programação funcional                    45
# 18                Boas práticas em Java                    40
# 19          Orientação objetos com Java                    46

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns=['Nome do curso', 'quantidade_de_alunos'])

# %%
muitas_matriculas.query('quantidade_de_alunos > 60')
# Out:
#           Nome do curso  quantidade_de_alunos
# 1         Java para Web                    63
# 2           C# para Web                    66
# 6         .NET para web                    68
# 16  Internet das coisas                    66

# %%
muitas_matriculas
# Out:
#                           Nome do curso  quantidade_de_alunos
# 0                 Lógica de programação                    30
# 1                         Java para Web                    63
# 2                           C# para Web                    66
# 3                         Ruby on Rails                    56
# 4                      Cursos de Python                    19
# 5                         PHP com MySql                     3
# 6                         .NET para web                    68
# 7            Novas integrações com Java                    53
# 8                          TDD com Java                    29
# 9                   Código limpo com C#                    53
# 10  Preparatório para certificação Java                    26
# 11                      Hardware básico                    39
# 12                Persistência com .NET                    34
# 13                  Desenvolvendo jogos                    14
# 14                     Análise de dados                    34
# 15                   Estatística básica                    29
# 16                  Internet das coisas                    66
# 17                Programação funcional                    45
# 18                Boas práticas em Java                    40
# 19          Orientação objetos com Java                    46

# %%
muitas_matriculas.query('quantidade_de_alunos > 60')
# Out:
#           Nome do curso  quantidade_de_alunos
# 1         Java para Web                    63
# 2           C# para Web                    66
# 6         .NET para web                    68
# 16  Internet das coisas                    66

# %%
muitas_matriculas.query('quantidade_de_alunos > 70')
# Out:
# Empty DataFrame
# Columns: [Nome do curso, quantidade_de_alunos]
# Index: []

# %%
muitas_matriculas = muitas_matriculas.query('quantidade_de_alunos > 40')

# %%
muitas_matriculas
# Out:
#                   Nome do curso  quantidade_de_alunos
# 1                 Java para Web                    63
# 2                   C# para Web                    66
# 3                 Ruby on Rails                    56
# 6                 .NET para web                    68
# 7    Novas integrações com Java                    53
# 9           Código limpo com C#                    53
# 16          Internet das coisas                    66
# 17        Programação funcional                    45
# 19  Orientação objetos com Java                    46

# %% [markdown]
# ## `Escrevendo no banco`

# %%
muitas_matriculas.to_sql('muitas_matriculas', con=engine)

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Nomes dos alunos e alunas da próxima turma

# %%
matriculas_por_curso.head(20)
# Out:
#           quantidade_de_alunos                        Nome do curso
# id_curso
# 0                           30                Lógica de programação
# 1                           63                        Java para Web
# 2                           66                          C# para Web
# 3                           56                        Ruby on Rails
# 4                           19                     Cursos de Python
# 5                            3                        PHP com MySql
# 6                           68                        .NET para web
# 7                           53           Novas integrações com Java
# 8                           29                         TDD com Java
# 9                           53                  Código limpo com C#
# 10                          26  Preparatório para certificação Java
# 11                          39                      Hardware básico
# 12                          34                Persistência com .NET
# 13                          14                  Desenvolvendo jogos
# 14                          34                     Análise de dados
# 15                          29                   Estatística básica
# 16                          66                  Internet das coisas
# 17                          45                Programação funcional
# 18                          40                Boas práticas em Java
# 19                          46          Orientação objetos com Java

# %%
matriculas
# Out:
#      id_aluno  id_curso
# 0         235        11
# 1          43         3
# 2          43         2
# 3         304        18
# 4         304        16
# ..        ...       ...
# 808       383        16
# 809       383         2
# 810       383        12
# 811       366         1
# 812       366        11
#
# [813 rows x 2 columns]

# %%
id_curso = 16
proxima_turma = matriculas.query("id_curso == {}".format(id_curso))
proxima_turma
# Out:
#      id_aluno  id_curso
# 4         304        16
# 29        218        16
# 86        297        16
# 101       391        16
# 107       233        16
# ..        ...       ...
# 763        69        16
# 765       209        16
# 775       225        16
# 787        97        16
# 808       383        16
#
# [66 rows x 2 columns]

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno                 dominio                         email  \
# 193   KAUAN        84  @dominiodoemail.com.br   kauan@dominiodoemail.com.br
# 59   MANUEL        51  @dominiodoemail.com.br  manuel@dominiodoemail.com.br
# 195  WALTER       231     @servicodoemail.com     walter@servicodoemail.com
#
#      matriculas
# 193           2
# 59            2
# 195           2

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso    nome                 dominio  \
# id_aluno
# 2               16   CESAR     @servicodoemail.com
# 11              16   PAULO     @servicodoemail.com
# 13              16     EVA     @servicodoemail.com
# 14              16   SUELI     @servicodoemail.com
# 19              16  VALMIR     @servicodoemail.com
# ...            ...     ...                     ...
# 383             16  ALVARO     @servicodoemail.com
# 391             16  RAQUEL  @dominiodoemail.com.br
# 394             16  JOELMA     @servicodoemail.com
# 397             16  LILIAN  @dominiodoemail.com.br
# 400             16   FABIO     @servicodoemail.com
#
#                                  email  matriculas
# id_aluno
# 2             cesar@servicodoemail.com           2
# 11            paulo@servicodoemail.com           2
# 13              eva@servicodoemail.com           2
# 14            sueli@servicodoemail.com           2
# 19           valmir@servicodoemail.com           3
# ...                                ...         ...
# 383          alvaro@servicodoemail.com           4
# 391       raquel@dominiodoemail.com.br           1
# 394          joelma@servicodoemail.com           3
# 397       lilian@dominiodoemail.com.br           5
# 400           fabio@servicodoemail.com           6
#
# [66 rows x 5 columns]

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome']
# Out:
# id_aluno
# 2       CESAR
# 11      PAULO
# 13        EVA
# 14      SUELI
# 19     VALMIR
#         ...
# 383    ALVARO
# 391    RAQUEL
# 394    JOELMA
# 397    LILIAN
# 400     FABIO
# Name: nome, Length: 66, dtype: object

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()
#Assim que se filtra mais ainda a nossa tabela
# Out:
#             nome
# id_aluno
# 2          CESAR
# 11         PAULO
# 13           EVA
# 14         SUELI
# 19        VALMIR
# ...          ...
# 383       ALVARO
# 391       RAQUEL
# 394       JOELMA
# 397       LILIAN
# 400        FABIO
#
# [66 rows x 1 columns]

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# Nome do curso    Internet das coisas
# Name: 16, dtype: object

# %%
nome_curso
# Out:
# Nome do curso    Internet das coisas
# Name: 16, dtype: object

# %%
nome_curso = nome_curso["Nome do curso"]
nome_curso
# Out:
# 'Internet das coisas'

# %%
proxima_turma = proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()

# %%
proxima_turma
# Out:
#             nome
# id_aluno
# 2          CESAR
# 11         PAULO
# 13           EVA
# 14         SUELI
# 19        VALMIR
# ...          ...
# 383       ALVARO
# 391       RAQUEL
# 394       JOELMA
# 397       LILIAN
# 400        FABIO
#
# [66 rows x 1 columns]

# %%
proxima_turma = proxima_turma.rename(columns = {'nome': 'Alunos do curso de {}'.format(nome_curso)})

# %%
proxima_turma.sample(5)
# Out:
#          Alunos do curso de Internet das coisas
# id_aluno
# 83                                       ISABEL
# 336                                     RICARDO
# 108                                       LUIZA
# 304                                   FRANCISCA
# 128                                     TAINARA

# %% [markdown]
# ```
# # Isto` está formatado como código`
# ```
#
# # Excel

# %%
proxima_turma.to_excel('proxima_turma.xlsx', index=False)

# %%
pd.read_excel('proxima_turma.xlsx')
# Out:
#    Alunos do curso de Internet das coisas
# 0                                   CESAR
# 1                                   PAULO
# 2                                     EVA
# 3                                   SUELI
# 4                                  VALMIR
# ..                                    ...
# 61                                 ALVARO
# 62                                 RAQUEL
# 63                                 JOELMA
# 64                                 LILIAN
# 65                                  FABIO
#
# [66 rows x 1 columns]
